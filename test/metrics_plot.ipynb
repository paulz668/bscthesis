# %%
import json
import matplotlib.pyplot as plt

# %%
cwd = "C:/Users/paulz/Documents/UNI/BBE/7.Semester/Bachelorarbeit/github/bscthesis/"
f = open(cwd + 'metrics.json')
metrics = json.load(f)

# %%
x = [1,2,3,4,5]
plt.plot(x, metrics['gb']['f1'][:5], label='F1 score')
plt.plot(x, metrics['gb']['accuracy'][:5], label='Accuracy')
plt.plot(x, metrics['gb']['precision'][:5], label='Precision')
plt.plot(x, metrics['gb']['recall'][:5], label='Recall')
plt.title('Evaluation metrics for time series CV schemes')
plt.legend()
plt.show()

# %%
plt.plot(x, metrics['rf']['f1'][:5], label='F1 score')
plt.plot(x, metrics['rf']['accuracy'][:5], label='Accuracy')
plt.plot(x, metrics['rf']['precision'][:5], label='Precision')
plt.plot(x, metrics['rf']['recall'][:5], label='Recall')
plt.title('Evaluation metrics for time series CV schemes')
plt.legend()
plt.show()
